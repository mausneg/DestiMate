# %%
import pandas as pd

# %%
df_ratings = pd.read_csv('raw/tourism_rating.csv')
df_tourims = pd.read_csv('../Tourism/tourism_encoded.csv')

# %%
df_tourims.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description  \
# 0  Monumen Nasional atau yang populer disingkat d...
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...
# 4  Atlantis Water Adventure atau dikenal dengan A...
#
#                                Category     City   Price  Rating  \
# 0                       Sejarah Edukasi  Jakarta   20000      46
# 1   Sejarah Edukasi,Seni Budaya,Kuliner  Jakarta       0      46
# 2                      Rekreasi,Hiburan  Jakarta  270000      46
# 3  Sejarah Edukasi,Seni Budaya,Rekreasi  Jakarta   10000      45
# ...

# %%
df_tourims.drop(df_tourims.columns[2:], axis=1, inplace=True)
df_tourims.head()
# Out:
#    Place_Id                         Place_Name
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure

# %%
df_ratings.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
df_ratings.shape, df_tourims.shape
# Out:
# ((10000, 3), (437, 2))

# %%
new_df = pd.merge(df_tourims,df_ratings, on='Place_Id', how='inner') 
new_df.head()
# Out:
#    Place_Id        Place_Name  User_Id  Place_Ratings
# 0         1  Monumen Nasional       36              4
# 1         1  Monumen Nasional       38              2
# 2         1  Monumen Nasional       64              2
# 3         1  Monumen Nasional       74              2
# 4         1  Monumen Nasional       86              4

# %%
new_df.shape
# Out:
# (10000, 4)

# %%
new_df.to_csv('ratings.csv', index=False)
